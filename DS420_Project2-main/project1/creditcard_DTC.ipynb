# %% [markdown]
# # Decision Tree Classification
#
# ##### Author: Cody Pierce
# ##### Part of Step 4: Train Algorithms

# %%
from sklearn.pipeline import Pipeline

from sklearn.tree import DecisionTreeClassifier

import math
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

from creditcard_preparation import create_creditcard_pipeline, prepare_creditcard_data

# %%
X_train, X_dev, X_test, y_train, y_dev, y_test = prepare_creditcard_data((1/10,1/10))

# %% [markdown]
# ### Grid search for best hyperparameters

# %%
# Focus on main hyperparameters of interest: Criterion and Max Depth
# Tested separately to save time

def grid_search_hyper_params_mainfocus(X_train, y_train):
    
    param_grid = {'criterion':['gini','entropy','log_loss'],
                   'max_depth':[2,4,6,8,10,None]}

    print("Training ...")
    grid = GridSearchCV(DecisionTreeClassifier(), 
                        param_grid, 
                        return_train_score = True,
                        refit = True, 
                        verbose = 3,
                        n_jobs=1, 
                        cv = 3) 

    # Fit model for grid search
    grid.fit(X_train, y_train) 

    # print best parameters after tuning 
    print("Grid searching is done!")
    print("The best score: ", grid.best_score_)
    print("The best hyperparameters:")
    print(grid.best_params_)
    return grid

# %%
# Grid search for best parameters (focus on main hyperparameters of interest)

grid_search_hyper_params_mainfocus(X_train, y_train)
# Out:
# Training ...
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# [CV 1/3] END criterion=gini, max_depth=2;, score=(train=0.936, test=0.938) total time=   4.4s
# [CV 2/3] END criterion=gini, max_depth=2;, score=(train=0.938, test=0.936) total time=   4.0s
# [CV 3/3] END criterion=gini, max_depth=2;, score=(train=0.934, test=0.934) total time=   3.9s
# [CV 1/3] END criterion=gini, max_depth=4;, score=(train=0.953, test=0.953) total time=   7.7s
# [CV 2/3] END criterion=gini, max_depth=4;, score=(train=0.953, test=0.951) total time=   7.7s
# [CV 3/3] END criterion=gini, max_depth=4;, score=(train=0.950, test=0.950) total time=   7.6s
# [CV 1/3] END criterion=gini, max_depth=6;, score=(train=0.965, test=0.965) total time=  11.3s
# [CV 2/3] END criterion=gini, max_depth=6;, score=(train=0.965, test=0.964) total time=  11.2s
# [CV 3/3] END criterion=gini, max_depth=6;, score=(train=0.965, test=0.965) total time=  11.4s
# [CV 1/3] END criterion=gini, max_depth=8;, score=(train=0.975, test=0.973) total time=  14.9s
# [CV 2/3] END criterion=gini, max_depth=8;, score=(train=0.976, test=0.975) total time=  14.8s
# [CV 3/3] END criterion=gini, max_depth=8;, score=(train=0.976, test=0.975) total time=  14.9s
# [CV 1/3] END criterion=gini, max_depth=10;, score=(train=0.987, test=0.985) total time=  18.1s
# [CV 2/3] END criterion=gini, max_depth=10;, score=(train=0.986, test=0.984) total time=  18.2s
# [CV 3/3] END criterion=gini, max_depth=10;, score=(train=0.987, test=0.985) total time=  18.3s
# [CV 1/3] END criterion=gini, max_depth=None;, score=(train=1.000, test=0.997) total time=  36.7s
# [CV 2/3] END criterion=gini, max_depth=None;, score=(train=1.000, test=0.997) total time=  35.0s
# [CV 3/3] END criterion=gini, max_depth=None;, score=(train=1.000, test=0.997) total time=  34.1s
# [CV 1/3] END criterion=entropy, max_depth=2;, score=(train=0.929, test=0.931) total time=   4.9s
# [CV 2/3] END criterion=entropy, max_depth=2;, score=(train=0.931, test=0.930) total time=   4.7s
# [CV 3/3] END criterion=entropy, max_depth=2;, score=(train=0.930, test=0.929) total time=   4.7s
# [CV 1/3] END criterion=entropy, max_depth=4;, score=(train=0.948, test=0.949) total time=   9.3s
# [CV 2/3] END criterion=entropy, max_depth=4;, score=(train=0.950, test=0.949) total time=   9.6s
# [CV 3/3] END criterion=entropy, max_depth=4;, score=(train=0.948, test=0.948) total time=   9.2s
# [CV 1/3] END criterion=entropy, max_depth=6;, score=(train=0.958, test=0.958) total time=  13.7s
# [CV 2/3] END criterion=entropy, max_depth=6;, score=(train=0.958, test=0.957) total time=  13.6s
# [CV 3/3] END criterion=entropy, max_depth=6;, score=(train=0.959, test=0.959) total time=  13.6s
# [CV 1/3] END criterion=entropy, max_depth=8;, score=(train=0.971, test=0.971) total time=  17.2s
# [CV 2/3] END criterion=entropy, max_depth=8;, score=(train=0.972, test=0.971) total time=  17.2s
# [CV 3/3] END criterion=entropy, max_depth=8;, score=(train=0.970, test=0.970) total time=  17.2s
# [CV 1/3] END criterion=entropy, max_depth=10;, score=(train=0.984, test=0.982) total time=  19.9s
# [CV 2/3] END criterion=entropy, max_depth=10;, score=(train=0.984, test=0.983) total time=  20.1s
# [CV 3/3] END criterion=entropy, max_depth=10;, score=(train=0.983, test=0.982) total time=  19.3s
# [CV 1/3] END criterion=entropy, max_depth=None;, score=(train=1.000, test=0.998) total time=  22.0s
# [CV 2/3] END criterion=entropy, max_depth=None;, score=(train=1.000, test=0.998) total time=  21.5s
# [CV 3/3] END criterion=entropy, max_depth=None;, score=(train=1.000, test=0.998) total time=  20.5s
# [CV 1/3] END criterion=log_loss, max_depth=2;, score=(train=0.929, test=0.931) total time=   4.7s
# [CV 2/3] END criterion=log_loss, max_depth=2;, score=(train=0.931, test=0.930) total time=   4.8s
# [CV 3/3] END criterion=log_loss, max_depth=2;, score=(train=0.930, test=0.929) total time=   4.7s
# [CV 1/3] END criterion=log_loss, max_depth=4;, score=(train=0.948, test=0.949) total time=   9.2s
# [CV 2/3] END criterion=log_loss, max_depth=4;, score=(train=0.950, test=0.949) total time=   9.4s
# [CV 3/3] END criterion=log_loss, max_depth=4;, score=(train=0.948, test=0.948) total time=   9.4s
# [CV 1/3] END criterion=log_loss, max_depth=6;, score=(train=0.958, test=0.958) total time=  13.9s
# [CV 2/3] END criterion=log_loss, max_depth=6;, score=(train=0.958, test=0.957) total time=  13.8s
# [CV 3/3] END criterion=log_loss, max_depth=6;, score=(train=0.959, test=0.959) total time=  14.0s
# [CV 1/3] END criterion=log_loss, max_depth=8;, score=(train=0.971, test=0.971) total time=  16.9s
# [CV 2/3] END criterion=log_loss, max_depth=8;, score=(train=0.972, test=0.971) total time=  16.7s
# [CV 3/3] END criterion=log_loss, max_depth=8;, score=(train=0.970, test=0.970) total time=  13.5s
# [CV 1/3] END criterion=log_loss, max_depth=10;, score=(train=0.984, test=0.982) total time=  14.2s
# [CV 2/3] END criterion=log_loss, max_depth=10;, score=(train=0.984, test=0.983) total time=  13.9s
# [CV 3/3] END criterion=log_loss, max_depth=10;, score=(train=0.983, test=0.982) total time=  13.2s
# [CV 1/3] END criterion=log_loss, max_depth=None;, score=(train=1.000, test=0.998) total time=  15.1s
# [CV 2/3] END criterion=log_loss, max_depth=None;, score=(train=1.000, test=0.998) total time=  14.6s
# [CV 3/3] END criterion=log_loss, max_depth=None;, score=(train=1.000, test=0.998) total time=  14.0s
# Grid searching is done!
# The best score:  0.997823717072701
# The best hyperparameters:
# {'criterion': 'entropy', 'max_depth': None}
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(), n_jobs=1,
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [2, 4, 6, 8, 10, None]},
#              return_train_score=True, verbose=3)

# %% [markdown]
# #### Criterion:
# * Default value for criterion is Gini; Entropy seems to perform about the same but takes less time to train
#
#
# #### Max Depth:
# * Default value for max depth is None and is clearly the best option in terms of accuracy score
# * Increased runtime seems worthwhile

# %%
# Try other options with max depth at 1 to decrease runtime
# Focus on those with default values that are not None (or 0)

def grid_search_hyper_params_other(X_train, y_train):
    
    param_grid = {'criterion':['entropy'],
                   'splitter':['best','random'],
                   'min_samples_split':[2,3,5],
                   'min_samples_leaf':[1,3,5],
                   'min_weight_fraction_leaf':[0.0, 0.5],
                   'max_depth':[1]}

    print("Training ...")
    grid = GridSearchCV(DecisionTreeClassifier(), 
                        param_grid, 
                        return_train_score = True,
                        refit = True, 
                        verbose = 3,
                        n_jobs=1, 
                        cv = 3) 

   # Fit model for grid search
    grid.fit(X_train, y_train) 

    # print best parameters after tuning 
    print("Grid searching is done!")
    print("The best score: ", grid.best_score_)
    print("The best hyperparameters:")
    print(grid.best_params_)
    return grid

# %%
# Grid search for best parameters (other than criterion and max depth)

grid_search_hyper_params_other(X_train, y_train)
# Out:
# Training ...
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0, splitter=best;, score=(train=0.929, test=0.931) total time=   1.9s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0, splitter=best;, score=(train=0.931, test=0.930) total time=   1.8s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0, splitter=best;, score=(train=0.930, test=0.929) total time=   1.8s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0, splitter=random;, score=(train=0.733, test=0.733) total time=   0.1s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0, splitter=random;, score=(train=0.693, test=0.693) total time=   0.1s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0, splitter=random;, score=(train=0.842, test=0.841) total time=   0.1s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.5, splitter=best;, score=(train=0.500, test=0.500) total time=   1.3s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.5, splitter=best;, score=(train=0.500, test=0.500) total time=   1.3s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.5, splitter=best;, score=(train=0.923, test=0.923) total time=   1.2s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.5, splitter=random;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.5, splitter=random;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.5, splitter=random;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=3, min_weight_fraction_leaf=0.0, splitter=best;, score=(train=0.929, test=0.931) total time=   1.7s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=3, min_weight_fraction_leaf=0.0, splitter=best;, score=(train=0.931, test=0.930) total time=   1.7s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=3, min_weight_fraction_leaf=0.0, splitter=best;, score=(train=0.930, test=0.929) total time=   1.6s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=3, min_weight_fraction_leaf=0.0, splitter=random;, score=(train=0.883, test=0.883) total time=   0.1s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=3, min_weight_fraction_leaf=0.0, splitter=random;, score=(train=0.800, test=0.799) total time=   0.1s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=3, min_weight_fraction_leaf=0.0, splitter=random;, score=(train=0.706, test=0.707) total time=   0.1s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=3, min_weight_fraction_leaf=0.5, splitter=best;, score=(train=0.500, test=0.500) total time=   1.2s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=3, min_weight_fraction_leaf=0.5, splitter=best;, score=(train=0.500, test=0.500) total time=   1.2s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=3, min_weight_fraction_leaf=0.5, splitter=best;, score=(train=0.923, test=0.923) total time=   1.2s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=3, min_weight_fraction_leaf=0.5, splitter=random;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=3, min_weight_fraction_leaf=0.5, splitter=random;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=3, min_weight_fraction_leaf=0.5, splitter=random;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=5, min_weight_fraction_leaf=0.0, splitter=best;, score=(train=0.929, test=0.931) total time=   1.7s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=5, min_weight_fraction_leaf=0.0, splitter=best;, score=(train=0.931, test=0.930) total time=   1.7s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=5, min_weight_fraction_leaf=0.0, splitter=best;, score=(train=0.930, test=0.929) total time=   1.7s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=5, min_weight_fraction_leaf=0.0, splitter=random;, score=(train=0.612, test=0.613) total time=   0.1s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=5, min_weight_fraction_leaf=0.0, splitter=random;, score=(train=0.801, test=0.800) total time=   0.1s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=5, min_weight_fraction_leaf=0.0, splitter=random;, score=(train=0.883, test=0.883) total time=   0.1s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=5, min_weight_fraction_leaf=0.5, splitter=best;, score=(train=0.500, test=0.500) total time=   1.2s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=5, min_weight_fraction_leaf=0.5, splitter=best;, score=(train=0.500, test=0.500) total time=   1.3s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=5, min_weight_fraction_leaf=0.5, splitter=best;, score=(train=0.923, test=0.923) total time=   1.3s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=5, min_weight_fraction_leaf=0.5, splitter=random;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=5, min_weight_fraction_leaf=0.5, splitter=random;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=1, min_samples_split=5, min_weight_fraction_leaf=0.5, splitter=random;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=2, min_weight_fraction_leaf=0.0, splitter=best;, score=(train=0.929, test=0.931) total time=   1.7s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=2, min_weight_fraction_leaf=0.0, splitter=best;, score=(train=0.931, test=0.930) total time=   1.7s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=2, min_weight_fraction_leaf=0.0, splitter=best;, score=(train=0.930, test=0.929) total time=   1.6s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=2, min_weight_fraction_leaf=0.0, splitter=random;, score=(train=0.678, test=0.679) total time=   0.1s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=2, min_weight_fraction_leaf=0.0, splitter=random;, score=(train=0.602, test=0.602) total time=   0.1s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=2, min_weight_fraction_leaf=0.0, splitter=random;, score=(train=0.891, test=0.891) total time=   0.1s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=2, min_weight_fraction_leaf=0.5, splitter=best;, score=(train=0.500, test=0.500) total time=   1.3s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=2, min_weight_fraction_leaf=0.5, splitter=best;, score=(train=0.500, test=0.500) total time=   1.2s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=2, min_weight_fraction_leaf=0.5, splitter=best;, score=(train=0.923, test=0.923) total time=   1.3s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=2, min_weight_fraction_leaf=0.5, splitter=random;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=2, min_weight_fraction_leaf=0.5, splitter=random;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=2, min_weight_fraction_leaf=0.5, splitter=random;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=3, min_weight_fraction_leaf=0.0, splitter=best;, score=(train=0.929, test=0.931) total time=   1.7s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=3, min_weight_fraction_leaf=0.0, splitter=best;, score=(train=0.931, test=0.930) total time=   1.7s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=3, min_weight_fraction_leaf=0.0, splitter=best;, score=(train=0.930, test=0.929) total time=   1.7s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=3, min_weight_fraction_leaf=0.0, splitter=random;, score=(train=0.614, test=0.616) total time=   0.1s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=3, min_weight_fraction_leaf=0.0, splitter=random;, score=(train=0.824, test=0.822) total time=   0.1s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=3, min_weight_fraction_leaf=0.0, splitter=random;, score=(train=0.668, test=0.668) total time=   0.1s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=3, min_weight_fraction_leaf=0.5, splitter=best;, score=(train=0.500, test=0.500) total time=   1.2s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=3, min_weight_fraction_leaf=0.5, splitter=best;, score=(train=0.500, test=0.500) total time=   1.2s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=3, min_weight_fraction_leaf=0.5, splitter=best;, score=(train=0.923, test=0.923) total time=   1.3s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=3, min_weight_fraction_leaf=0.5, splitter=random;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=3, min_weight_fraction_leaf=0.5, splitter=random;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=3, min_weight_fraction_leaf=0.5, splitter=random;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=5, min_weight_fraction_leaf=0.0, splitter=best;, score=(train=0.929, test=0.931) total time=   1.6s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=5, min_weight_fraction_leaf=0.0, splitter=best;, score=(train=0.931, test=0.930) total time=   1.7s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=5, min_weight_fraction_leaf=0.0, splitter=best;, score=(train=0.930, test=0.929) total time=   1.7s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=5, min_weight_fraction_leaf=0.0, splitter=random;, score=(train=0.807, test=0.808) total time=   0.1s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=5, min_weight_fraction_leaf=0.0, splitter=random;, score=(train=0.751, test=0.749) total time=   0.1s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=5, min_weight_fraction_leaf=0.0, splitter=random;, score=(train=0.854, test=0.854) total time=   0.1s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=5, min_weight_fraction_leaf=0.5, splitter=best;, score=(train=0.500, test=0.500) total time=   1.2s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=5, min_weight_fraction_leaf=0.5, splitter=best;, score=(train=0.500, test=0.500) total time=   1.2s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=5, min_weight_fraction_leaf=0.5, splitter=best;, score=(train=0.923, test=0.923) total time=   1.2s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=5, min_weight_fraction_leaf=0.5, splitter=random;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=5, min_weight_fraction_leaf=0.5, splitter=random;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=3, min_samples_split=5, min_weight_fraction_leaf=0.5, splitter=random;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=2, min_weight_fraction_leaf=0.0, splitter=best;, score=(train=0.929, test=0.931) total time=   1.7s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=2, min_weight_fraction_leaf=0.0, splitter=best;, score=(train=0.931, test=0.930) total time=   1.7s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=2, min_weight_fraction_leaf=0.0, splitter=best;, score=(train=0.930, test=0.929) total time=   1.7s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=2, min_weight_fraction_leaf=0.0, splitter=random;, score=(train=0.895, test=0.895) total time=   0.1s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=2, min_weight_fraction_leaf=0.0, splitter=random;, score=(train=0.554, test=0.554) total time=   0.1s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=2, min_weight_fraction_leaf=0.0, splitter=random;, score=(train=0.891, test=0.890) total time=   0.1s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=2, min_weight_fraction_leaf=0.5, splitter=best;, score=(train=0.500, test=0.500) total time=   1.2s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=2, min_weight_fraction_leaf=0.5, splitter=best;, score=(train=0.500, test=0.500) total time=   1.2s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=2, min_weight_fraction_leaf=0.5, splitter=best;, score=(train=0.923, test=0.923) total time=   1.2s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=2, min_weight_fraction_leaf=0.5, splitter=random;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=2, min_weight_fraction_leaf=0.5, splitter=random;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=2, min_weight_fraction_leaf=0.5, splitter=random;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=3, min_weight_fraction_leaf=0.0, splitter=best;, score=(train=0.929, test=0.931) total time=   1.7s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=3, min_weight_fraction_leaf=0.0, splitter=best;, score=(train=0.931, test=0.930) total time=   1.7s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=3, min_weight_fraction_leaf=0.0, splitter=best;, score=(train=0.930, test=0.929) total time=   1.7s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=3, min_weight_fraction_leaf=0.0, splitter=random;, score=(train=0.781, test=0.781) total time=   0.1s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=3, min_weight_fraction_leaf=0.0, splitter=random;, score=(train=0.906, test=0.905) total time=   0.1s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=3, min_weight_fraction_leaf=0.0, splitter=random;, score=(train=0.826, test=0.825) total time=   0.1s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=3, min_weight_fraction_leaf=0.5, splitter=best;, score=(train=0.500, test=0.500) total time=   1.3s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=3, min_weight_fraction_leaf=0.5, splitter=best;, score=(train=0.500, test=0.500) total time=   1.2s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=3, min_weight_fraction_leaf=0.5, splitter=best;, score=(train=0.923, test=0.923) total time=   1.2s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=3, min_weight_fraction_leaf=0.5, splitter=random;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=3, min_weight_fraction_leaf=0.5, splitter=random;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=3, min_weight_fraction_leaf=0.5, splitter=random;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.0, splitter=best;, score=(train=0.929, test=0.931) total time=   1.7s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.0, splitter=best;, score=(train=0.931, test=0.930) total time=   1.7s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.0, splitter=best;, score=(train=0.930, test=0.929) total time=   1.7s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.0, splitter=random;, score=(train=0.618, test=0.619) total time=   0.1s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.0, splitter=random;, score=(train=0.629, test=0.628) total time=   0.1s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.0, splitter=random;, score=(train=0.919, test=0.920) total time=   0.1s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.5, splitter=best;, score=(train=0.500, test=0.500) total time=   1.3s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.5, splitter=best;, score=(train=0.500, test=0.500) total time=   1.2s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.5, splitter=best;, score=(train=0.923, test=0.923) total time=   1.2s
# [CV 1/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.5, splitter=random;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 2/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.5, splitter=random;, score=(train=0.500, test=0.500) total time=   0.1s
# [CV 3/3] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.5, splitter=random;, score=(train=0.500, test=0.500) total time=   0.1s
# Grid searching is done!
# The best score:  0.9299104855201996
# The best hyperparameters:
# {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'splitter': 'best'}
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(), n_jobs=1,
#              param_grid={'criterion': ['entropy'], 'max_depth': [1],
#                          'min_samples_leaf': [1, 3, 5],
#                          'min_samples_split': [2, 3, 5],
#                          'min_weight_fraction_leaf': [0.0, 0.5],
#                          'splitter': ['best', 'random']},
#              return_train_score=True, verbose=3)

# %% [markdown]
# * Overall: Default values seem to be the best choices for all parameters besides criterion ("entropy" seems to be faster while still maintaining performance)

# %% [markdown]
# ### Test model on test set using chosen hyperparameters

# %%
# Create the pipeline
pipeline = create_creditcard_pipeline()


# Create algorithm with parameters found during grid search
# Leave all parameters as default besides criterion
DTC_model = DecisionTreeClassifier(criterion="entropy")


# Combine the pipeline and the algorithm
pipeline_with_algo = Pipeline(steps=[
    ('preprocessor', pipeline),
    ('algo', DTC_model)
])

pipeline_with_algo.fit(X_train, y_train)
y_test_pred = pipeline_with_algo.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_test_pred)
precision = precision_score(y_test, y_test_pred)
recall = recall_score(y_test, y_test_pred)
f1 = f1_score(y_test, y_test_pred)


print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.9983293178340925
# Precision: 0.9975114787424205
# Recall: 0.999157421710434
# F1 Score: 0.9983337718144348
